# %%
import pandas as pd

# %%
listings = pd.read_csv('listings.csv')
listings.head()
calendar = pd.read_csv('calendar.csv')
calendar.head()
landmarks = pd.read_csv('Individual_Landmarks.csv')

# %%
listings_cleaned = listings.loc[:,['id', 'host_id', 'host_response_time', 'host_response_rate', 'neighbourhood_cleansed', 'latitude', 'longitude', 'accommodates', 'amenities', 'price', 'minimum_nights', 'maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value']]

listings_cleaned.head()
# Out:
#         id  host_id  host_response_time host_response_rate  \
# 0   2384.0     2613      within an hour               100%
# 1   7126.0    17928      within an hour               100%
# 2  10945.0    33004      within an hour                93%
# 3  12140.0    46734                 NaN                NaN
# 4  24833.0   101521  within a few hours                94%
#
#   neighbourhood_cleansed   latitude  longitude  accommodates  \
# 0              Hyde Park  41.787900 -87.587800             1
# 1              West Town  41.901660 -87.680210             2
# 2           Lincoln Park  41.911960 -87.639810             4
# 3           Lincoln Park  41.923570 -87.649470             3
# 4           Lincoln Park  41.925961 -87.656364             3
#
#                                            amenities     price  ...  \
# 0  ["Fire extinguisher", "Long term stays allowed...  $114.00   ...
# 1  ["Fire extinguisher", "Long term stays allowed...   $92.00   ...
# 2  ["Fire extinguisher", "Dishes and silverware",...  $170.00   ...
# 3  ["Fire extinguisher", "Free street parking", "...  $329.00   ...
# 4  ["Fire extinguisher", "Long term stays allowed...   $61.00   ...
#
#    maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# 0              60                     3.0                  1125.0
# 1              60                    30.4                  1125.0
# 2            1125                     4.0                  1125.0
# 3              10                     2.0                    10.0
# 4             395                    32.6                   395.0
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.99                    4.98                       4.99
# 1                  4.70                    4.84                       4.56
# 2                  4.65                    4.76                       4.78
# 3                  4.93                    4.67                       5.00
# 4                  4.29                    4.07                       4.00
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   4.99                         4.99                    4.96
# 1                   4.90                         4.87                    4.89
# 2                   4.82                         4.82                    4.99
# 3                   5.00                         5.00                    5.00
# 4                   4.13                         4.03                    4.90
#
#    review_scores_value
# 0                 4.94
# 1                 4.75
# 2                 4.65
# 3                 4.87
# 4                 4.20
#
# [5 rows x 21 columns]

# %%
calendar_cleaned = calendar.loc[calendar['available']=='f',['listing_id', 'date', 'available', 'price', 'adjusted_price']]
calendar_cleaned.head()
# Out:
#    listing_id       date available     price adjusted_price
# 0        2384  9/12/2023         f  $125.00        $125.00
# 1        2384  9/13/2023         f  $125.00        $125.00
# 2        2384  9/14/2023         f  $125.00        $125.00
# 3        2384  9/15/2023         f  $100.00        $100.00
# 4        2384  9/16/2023         f  $100.00        $100.00

# %%
landmarks_cleaned = landmarks.loc[:, ['LANDMARK NAME', 'ID', 'LATITUDE','LONGITUDE', 'LOCATION']]
landmarks_cleaned.head()
# Out:
#                                        LANDMARK NAME     ID   LATITUDE  \
# 0            Vassar Swiss Underwear Company Building  L-265  41.931627
# 1                               Mathilde Eliel House  L- 89  41.819256
# 2                                 Manhattan Building  L-139  41.876066
# 3  Machinery Hall at Illinois Institute of Techno...  L- 12  41.835161
# 4                             Melissa Ann Elam House  L- 88  41.808530
#
#    LONGITUDE                         LOCATION
# 0 -87.692100  (41.9316266084, -87.6921000957)
# 1 -87.602788   (41.819255751, -87.6027879992)
# 2 -87.628964  (41.8760657234, -87.6289644505)
# 3 -87.629221  (41.8351614122, -87.6292212235)
# 4 -87.617204   (41.808529769, -87.6172043949)

# %%
listings_dropped = listings_cleaned.dropna()
listings_dropped
# Out:
#                 id    host_id  host_response_time host_response_rate  \
# 0     2.384000e+03       2613      within an hour               100%
# 1     7.126000e+03      17928      within an hour               100%
# 2     1.094500e+04      33004      within an hour                93%
# 4     2.483300e+04     101521  within a few hours                94%
# 5     2.587900e+04     101521  within a few hours                94%
# ...            ...        ...                 ...                ...
# 8449  9.680970e+17   82950654      within an hour               100%
# 8455  9.683600e+17  430882859  within a few hours               100%
# 8468  9.697680e+17  235678953      within an hour                99%
# 8475  9.703900e+17   17266955  within a few hours                82%
# 8491  9.730150e+17   67751745      within an hour               100%
#
#      neighbourhood_cleansed   latitude  longitude  accommodates  \
# 0                 Hyde Park  41.787900 -87.587800             1
# 1                 West Town  41.901660 -87.680210             2
# 2              Lincoln Park  41.911960 -87.639810             4
# 4              Lincoln Park  41.925961 -87.656364             3
# 5              Lincoln Park  41.924990 -87.655730             6
# ...                     ...        ...        ...           ...
# 8449                 Austin  41.900071 -87.751783            12
# 8455                 Uptown  41.955383 -87.649993             3
# 8468         Near West Side  41.887883 -87.643916             6
# 8475              Edgewater  41.988150 -87.673240             2
# 8491        Near North Side  41.896538 -87.638062             6
#
#                                               amenities     price  ...  \
# 0     ["Fire extinguisher", "Long term stays allowed...  $114.00   ...
# 1     ["Fire extinguisher", "Long term stays allowed...   $92.00   ...
# 2     ["Fire extinguisher", "Dishes and silverware",...  $170.00   ...
# 4     ["Fire extinguisher", "Long term stays allowed...   $61.00   ...
# 5     ["Fire extinguisher", "Long term stays allowed...   $95.00   ...
# ...                                                 ...       ...  ...
# 8449  ["Fire extinguisher", "Long term stays allowed...  $299.00   ...
# 8455  ["Fire extinguisher", "Long term stays allowed...  $109.00   ...
# 8468  ["Fire extinguisher", "Long term stays allowed...  $216.00   ...
# 8475  ["Fire extinguisher", "TV", "Wifi", "Smoke ala...   $90.00   ...
# 8491  ["Fire extinguisher", "Long term stays allowed...  $367.00   ...
#
#       maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# 0                 60                     3.0                  1125.0
# 1                 60                    30.4                  1125.0
# 2               1125                     4.0                  1125.0
# 4                395                    32.6                   395.0
# 5                300                    46.7                   300.0
# ...              ...                     ...                     ...
# 8449             365                     2.0                   365.0
# 8455             365                     2.0                   365.0
# 8468             365                     2.0                   365.0
# 8475             365                     2.0                   365.0
# 8491             999                     4.8                   999.0
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                     4.99                    4.98                       4.99
# 1                     4.70                    4.84                       4.56
# 2                     4.65                    4.76                       4.78
# 4                     4.29                    4.07                       4.00
# 5                     4.30                    4.57                       4.24
# ...                    ...                     ...                        ...
# 8449                  5.00                    5.00                       5.00
# 8455                  5.00                    5.00                       5.00
# 8468                  3.00                    2.00                       3.00
# 8475                  5.00                    5.00                       5.00
# 8491                  5.00                    5.00                       5.00
#
#       review_scores_checkin  review_scores_communication  \
# 0                      4.99                         4.99
# 1                      4.90                         4.87
# 2                      4.82                         4.82
# 4                      4.13                         4.03
# 5                      4.13                         4.13
# ...                     ...                          ...
# 8449                   5.00                         5.00
# 8455                   5.00                         5.00
# 8468                   4.00                         4.00
# 8475                   5.00                         5.00
# 8491                   5.00                         5.00
#
#       review_scores_location  review_scores_value
# 0                       4.96                 4.94
# 1                       4.89                 4.75
# 2                       4.99                 4.65
# 4                       4.90                 4.20
# 5                       4.92                 4.35
# ...                      ...                  ...
# 8449                    5.00                 5.00
# 8455                    5.00                 5.00
# 8468                    4.00                 2.00
# 8475                    5.00                 5.00
# 8491                    5.00                 5.00
#
# [6212 rows x 21 columns]

# %%
missing_values_listings = listings_cleaned.loc[~listings_cleaned.id.isin(listings_dropped.id), :]
missing_values_listings
# Out:
#                 id    host_id host_response_time host_response_rate  \
# 3     1.214000e+04      46734                NaN                NaN
# 7     3.773800e+04     162364                NaN                NaN
# 18    2.503540e+05    1311953                NaN                NaN
# 22    2.901550e+05    1505878                NaN                NaN
# 23    3.121920e+05    1505878                NaN                NaN
# ...            ...        ...                ...                ...
# 8523  9.769990e+17   11120895     within an hour               100%
# 8524  9.771450e+17  260588213     within an hour               100%
# 8525  9.777470e+17  536514763                NaN                NaN
# 8526  9.779810e+17  107434423     within an hour               100%
# 8527  9.782650e+17  518917937     within an hour               100%
#
#      neighbourhood_cleansed   latitude  longitude  accommodates  \
# 3              Lincoln Park  41.923570 -87.649470             3
# 7                    Uptown  41.973030 -87.665670             2
# 18          Near South Side  41.859230 -87.621980             2
# 22               Bridgeport  41.827120 -87.640460             6
# 23               Bridgeport  41.827410 -87.639340             6
# ...                     ...        ...        ...           ...
# 8523         Near West Side  41.875333 -87.689492            13
# 8524          Mckinley Park  41.825997 -87.669151             1
# 8525         West Englewood  41.763133 -87.656318             4
# 8526                   Loop  41.869479 -87.631225             2
# 8527              Lake View  41.948470 -87.657230             8
#
#                                               amenities     price  ...  \
# 3     ["Fire extinguisher", "Free street parking", "...  $329.00   ...
# 7     ["Fire extinguisher", "Host greets you", "Dish...  $110.00   ...
# 18    ["Long term stays allowed", "Host greets you",...  $170.00   ...
# 22    ["Fire extinguisher", "Long term stays allowed...  $130.00   ...
# 23    ["Fire extinguisher", "Long term stays allowed...  $146.00   ...
# ...                                                 ...       ...  ...
# 8523  ["Fire extinguisher", "Long term stays allowed...  $438.00   ...
# 8524  ["Fire extinguisher", "Long term stays allowed...   $32.00   ...
# 8525  ["TV", "Keypad", "Wifi", "Self check-in", "Sec...   $24.00   ...
# 8526  ["Long term stays allowed", "Hair dryer", "Cof...  $127.00   ...
# 8527  ["Fire extinguisher", "Dishes and silverware",...  $366.00   ...
#
#       maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# 3                 10                     2.0                    10.0
# 7               1125                    32.0                  1125.0
# 18               365                   180.0                   365.0
# 22                90                    32.0                  1125.0
# 23               120                    32.0                  1125.0
# ...              ...                     ...                     ...
# 8523             365                    30.0                   365.0
# 8524             365                     2.0                   365.0
# 8525             365                    32.0                   365.0
# 8526            1125                   354.1                  1125.0
# 8527             365                     2.0                  1125.0
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 3                     4.93                    4.67                       5.00
# 7                     4.99                    4.99                       5.00
# 18                    4.84                    4.94                       4.53
# 22                    4.84                    4.94                       4.62
# 23                    4.74                    4.72                       4.82
# ...                    ...                     ...                        ...
# 8523                   NaN                     NaN                        NaN
# 8524                   NaN                     NaN                        NaN
# 8525                   NaN                     NaN                        NaN
# 8526                   NaN                     NaN                        NaN
# 8527                   NaN                     NaN                        NaN
#
#       review_scores_checkin  review_scores_communication  \
# 3                      5.00                         5.00
# 7                      4.99                         4.98
# 18                     4.94                         4.97
# 22                     4.96                         5.00
# 23                     4.95                         4.97
# ...                     ...                          ...
# 8523                    NaN                          NaN
# 8524                    NaN                          NaN
# 8525                    NaN                          NaN
# 8526                    NaN                          NaN
# 8527                    NaN                          NaN
#
#       review_scores_location  review_scores_value
# 3                       5.00                 4.87
# 7                       4.92                 4.98
# 18                      4.82                 4.47
# 22                      4.72                 4.86
# 23                      4.64                 4.85
# ...                      ...                  ...
# 8523                     NaN                  NaN
# 8524                     NaN                  NaN
# 8525                     NaN                  NaN
# 8526                     NaN                  NaN
# 8527                     NaN                  NaN
#
# [2287 rows x 21 columns]

# %%
calendar_unique = calendar_cleaned.nunique()
calendar_unique
# Out:
# listing_id        2723
# date               365
# available            1
# price             1345
# adjusted_price    1349
# dtype: int64
